# %%
import pandas as pd
import numpy as np
import os
df = pd.read_csv('data'+os.sep+'wine2.csv')

X=df[['pH','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates']]
y=df['quality']
df
# found a dataset for the wine quality from 1-10, focused on the wines that are ranked as 7-8 quality as the most populated groups
# https://www.kaggle.com/yasserh/wine-quality-dataset
# removed the ranks from 1-6 and 9-10 directly from the .csv file in Excel, NB:the dataset has only wines ranked 3 and above
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.3              0.65         0.00             1.2      0.065
# 1              7.8              0.58         0.02             2.0      0.073
# 2              8.5              0.28         0.56             1.8      0.092
# 3              8.1              0.38         0.28             2.1      0.066
# 4              8.0              0.59         0.16             1.8      0.065
# ..             ...               ...          ...             ...        ...
# 154            6.6              0.56         0.14             2.4      0.064
# 155            8.4              0.37         0.43             2.3      0.063
# 156            7.4              0.36         0.30             1.8      0.074
# 157            7.0              0.56         0.17             1.7      0.065
# 158            6.7              0.32         0.44             2.4      0.061
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=36)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz
export_graphviz(model, 'winee.dot', 
                feature_names = ['pH','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates'],
                class_names= df['quality'].unique())
pred = model.predict(X_test)

# %%
#classification report

from sklearn.metrics import classification_report
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        eight       0.33      0.33      0.33         3
#        seven       0.85      0.85      0.85        13
#
#     accuracy                           0.75        16
#    macro avg       0.59      0.59      0.59        16
# weighted avg       0.75      0.75      0.75        16
